# %%
Text cell <fwU2iooz85jt>
#%% [markdown]
## Exercises

Answer the questions or complete the tasks outlined in bold below, use the specific method described if applicable.

Text cell <SzBQQ_ml85j1>
#%% [markdown]
** What is 7 to the power of 4?**

Code cell <UhvE4PBC85j3>
#%% [code]
7**4
Execution output
0KB
	text/plain
		2401

Text cell <ds8G9S8j85j6>
#%% [markdown]
** Split this string:**

    s = "Hi there Sam!"
    
**into a list. **

Code cell <GD_Tls3H85j7>
#%% [code]
s = "Hi there Sam!"
s = s.split(" ")
print(s)
Execution output
0KB
	Stream
		['Hi', 'there', 'Sam!']

Text cell <_bBNOu-785j9>
#%% [markdown]
** Given the variables:**

    planet = "Earth"
    diameter = 12742

** Use .format() to print the following string: **

    The diameter of Earth is 12742 kilometers.

Code cell <2TrzmDcS85j->
#%% [code]
planet = "Earth"
diameter = 12742
print("The diameter of {} is {} kilometers.".format(planet,diameter))
Execution output
0KB
	Stream
		The diameter of Earth is 12742 kilometers.

Text cell <QAKtN7Hh85kB>
#%% [markdown]
** Given this nested list, use indexing to grab the word "hello" **

Code cell <-7dzQDyK85kD>
#%% [code]
lst = [1,2,[3,4],[5,[100,200,['hello']],23,11],1,7]

Code cell <6m5C0sTW85kE>
#%% [code]
lst[3][1][2][0]
Execution output
0KB
	text/plain
		'hello'

Text cell <9Ma7M4a185kF>
#%% [markdown]
** Given this nest dictionary grab the word "hello". Be prepared, this will be annoying/tricky **

Code cell <vrYAxSYN85kG>
#%% [code]
d = {'k1':[1,2,3,{'tricky':['oh','man','inception',{'target':[1,2,3,'hello']}]}]}

Code cell <FlILSdm485kH>
#%% [code]
d["k1"][3]["tricky"][3]["target"][3]

Execution output
0KB
	text/plain
		'hello'

Text cell <FInV_FKB85kI>
#%% [markdown]
** What is the main difference between a tuple and a list? **

Code cell <_VBWf00q85kJ>
#%% [code]
print("List and Tuple in Python are the classes of Python Data Structures. The list is dynamic, whereas the tuple has static characteristics. This means that lists can be modified whereas tuples cannot be modified, the tuple is faster than the list because of static in nature")
Execution output
0KB
	Stream
		List and Tuple in Python are the classes of Python Data Structures. The list is dynamic, whereas the tuple has static characteristics. This means that lists can be modified whereas tuples cannot be modified, the tuple is faster than the list because of static in nature

Text cell <zP-j0HZj85kK>
#%% [markdown]
** Create a function that grabs the email website domain from a string in the form: **

    user@domain.com
    
**So for example, passing "user@domain.com" would return: domain.com**

Code cell <unvEAwjk85kL>
#%% [code]
def email(email):
  return email.split("@")[1]

Code cell <Gb9dspLC85kL>
#%% [code]
email_var = "user@domain.com"
email(email_var)
Execution output
0KB
	text/plain
		'domain.com'

Text cell <gYydb-y085kM>
#%% [markdown]
** Create a basic function that returns True if the word 'dog' is contained in the input string. Don't worry about edge cases like a punctuation being attached to the word dog, but do account for capitalization. **

Code cell <Q4ldLGV785kM>
#%% [code]
def word_found(word):
  return True if "dog" in str(word) else False  

Code cell <EqH6b7yv85kN>
#%% [code]
word = "Don't worry about edge cases like a punctuation being attached to the word dog, but do account for capitalization"
word_found(word)
Execution output
0KB
	text/plain
		True

Text cell <AyHQFALC85kO>
#%% [markdown]
** Create a function that counts the number of times the word "dog" occurs in a string. Again ignore edge cases. **

Code cell <6hdc169585kO>
#%% [code]
def word_found_counts(word):
  return word.count("dog")

Code cell <igzsvHb385kO>
#%% [code]
word = "Don't worry about edge cases like a punctuation being attached to the word dog, but do account for capitalization dogs"
word_found_counts(word)
Execution output
0KB
	text/plain
		2

Text cell <3n7jJt4k85kP>
#%% [markdown]
### Problem
**You are driving a little too fast, and a police officer stops you. Write a function
  to return one of 3 possible results: "No ticket", "Small ticket", or "Big Ticket". 
  If your speed is 60 or less, the result is "No Ticket". If speed is between 61 
  and 80 inclusive, the result is "Small Ticket". If speed is 81 or more, the result is "Big    Ticket". Unless it is your birthday (encoded as a boolean value in the parameters of the function) -- on your birthday, your speed can be 5 higher in all 
  cases. **

Code cell <nvXMkvWk85kQ>
#%% [code]
def caught_speeding(speed, is_birthday):
    
    if is_birthday:
        speeding = speed + 5
    else:
        speeding = speed
    if speeding <= 80 :
        return 'Small Ticket'
    elif speeding <= 60:
        return 'No Ticket'
    else:
        return 'Big Ticket'

Code cell <BU_UZcyk85kS>
#%% [code]
print(caught_speeding(81,True))
Execution output
0KB
	Stream
		Big Ticket

Code cell <p1AGJ7DM85kR>
#%% [code]
print(caught_speeding(80,False))
Execution output
0KB
	Stream
		Small Ticket

Text cell <Tie4rC7_kAOC>
#%% [markdown]
Create an employee list with basic salary values(at least 5 values for 5 employees)  and using a for loop retreive each employee salary and calculate total salary expenditure. 

Code cell <R5-CdXSKjacN>
#%% [code]
employee = [["Ashwin",600000],["Jagan",200000],["Hagith",300000],["Karthi",400000],["Rathan",500000]]
total = 0
for i in employee:
  
  total += i[1]
  
print(total)


Execution output
0KB
	Stream
		2000000

Text cell <-L1aiFqRkF5s>
#%% [markdown]
Create two dictionaries in Python:

First one to contain fields as Empid,  Empname,  Basicpay

Second dictionary to contain fields as DeptName,  DeptId.

Combine both dictionaries. 

Code cell <8ugVoEe0kOsk>
#%% [code]
first_emp = {
    "Empid" : 1,
    "Empname": "Ashwin",
    "Basicpay" : 700000.00
}

second_dict = {
    "DeptName" : "Information Technology",
    "DeptId" : "19BIT010"
}

first_emp.update(second_dict)
first_emp
Execution output
0KB
	Stream
		{'Empid': 1, 'Empname': 'Ashwin', 'Basicpay': 700000.0, 'DeptName': 'Information Technology', 'DeptId': '19BIT010'}
